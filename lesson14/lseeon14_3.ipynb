# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
sizes = [20, 30, 40, 10]
fig, ax = plt.subplots()

ax.pie (sizes, labels=labels,
       colors =['yellow', 'green', 'red', 'blue'])

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x744640dec6a0>,
#   <matplotlib.patches.Wedge at 0x744640d8b8e0>,
#   <matplotlib.patches.Wedge at 0x744640decf70>,
#   <matplotlib.patches.Wedge at 0x744640ded3f0>],
#  [Text(0.8899186877588753, 0.6465637858537406, 'Nokia'),
#   Text(-0.64656382751384, 0.8899186574910392, 'Samsung'),
#   Text(-0.3399185762739153, -1.046162206115244, 'Apple'),
#   Text(1.0461622140716127, -0.3399185517867209, 'Lumia')])

# %%
import matplotlib.pyplot as plt

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
sizes = [20, 30, 40, 10]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%',
       pctdistance=1.25, labeldistance=.6)

ax.pie (sizes, labels=labels,
       colors =['yellow', 'green', 'red', 'blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x74463be941c0>,
#   <matplotlib.patches.Wedge at 0x74463be94280>,
#   <matplotlib.patches.Wedge at 0x74463be949a0>,
#   <matplotlib.patches.Wedge at 0x744640c442b0>],
#  [Text(0.8899186877588753, 0.6465637858537406, 'Nokia'),
#   Text(-0.64656382751384, 0.8899186574910392, 'Samsung'),
#   Text(-0.3399185762739153, -1.046162206115244, 'Apple'),
#   Text(1.0461622140716127, -0.3399185517867209, 'Lumia')])
