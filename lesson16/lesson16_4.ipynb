# %%
import pandas as pd

df1 = pd.read_csv('上市公司資料.csv')
df1
# Out:
#         出表日期   資料年月  公司代號 公司名稱   產業別  營業收入-當月營收  營業收入-上月營收  營業收入-去年當月營收  \
# 0    1110912  11108  1102   亞泥  水泥工業    7069221    7864622      7193266
# 1    1110912  11108  1108   幸福  水泥工業     390053     326691       249977
# 2    1110912  11108  1109   信大  水泥工業     478276     557403       591358
# 3    1110912  11108  1110   東泥  水泥工業     176935     134470       109276
# 4    1110912  11108  1213   大飲  食品工業      38696      29503        42312
# ..       ...    ...   ...  ...   ...        ...        ...          ...
# 834  1110912  11108  9942   茂順    其他     352730     349111       336002
# 835  1110912  11108  9943  好樂迪  觀光事業     212912     197756         5090
# 836  1110912  11108  9944   新麗    其他     179660     231139       178668
# 837  1110912  11108  9955   佳龍    其他      81881      85625       109319
# 838  1110912  11108  9958  世紀鋼  鋼鐵工業     757968     651699      1073536
#
#      營業收入-上月比較增減(%)  營業收入-去年同月增減(%)  累計營業收入-當月累計營收  累計營業收入-去年累計營收  \
# ...

# %%
import pandas as pd

df1 = pd.read_csv('上市公司資料.csv')

df2 = df1.drop(index=0,)

# %%
df3=df2.drop(columns=['出表日期','資料年月','營業收入-上月比較增減(%)','營業收入-去年同月增減(%)','營業收入-去年當月營收'
                      ,'累計營業收入-當月累計營收','累計營業收入-前期比較增減(%)','備註','累計營業收入-去年累計營收'])
df3
# Out:
#      公司代號 公司名稱   產業別  營業收入-當月營收  營業收入-上月營收
# 1    1108   幸福  水泥工業     390053     326691
# 2    1109   信大  水泥工業     478276     557403
# 3    1110   東泥  水泥工業     176935     134470
# 4    1213   大飲  食品工業      38696      29503
# 5    1215   卜蜂  食品工業    2393814    2400161
# ..    ...  ...   ...        ...        ...
# 834  9942   茂順    其他     352730     349111
# 835  9943  好樂迪  觀光事業     212912     197756
# 836  9944   新麗    其他     179660     231139
# 837  9955   佳龍    其他      81881      85625
# 838  9958  世紀鋼  鋼鐵工業     757968     651699
#
# [838 rows x 5 columns]

# %%
df4=df3.set_index('公司代號')
df4
# Out:
#      公司名稱   產業別  營業收入-當月營收  營業收入-上月營收
# 公司代號
# 1108   幸福  水泥工業     390053     326691
# 1109   信大  水泥工業     478276     557403
# 1110   東泥  水泥工業     176935     134470
# 1213   大飲  食品工業      38696      29503
# 1215   卜蜂  食品工業    2393814    2400161
# ...   ...   ...        ...        ...
# 9942   茂順    其他     352730     349111
# 9943  好樂迪  觀光事業     212912     197756
# 9944   新麗    其他     179660     231139
# 9955   佳龍    其他      81881      85625
# 9958  世紀鋼  鋼鐵工業     757968     651699
#
# [838 rows x 4 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838 entries, 1108 to 9958
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   公司名稱       838 non-null    object
#  1   產業別        838 non-null    object
#  2   營業收入-當月營收  838 non-null    int64
#  3   營業收入-上月營收  838 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 32.7+ KB

# %%
df4['公司代號'] = df4['公司代號'].astype(str)
nums = []
for num in df4['公司代號']:
    try:
        nums.append(str(num))
    except:
        nums.append(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '公司代號'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df4['公司代號'] = df4['公司代號'].astype(str)
#       2 nums = []
# ...
