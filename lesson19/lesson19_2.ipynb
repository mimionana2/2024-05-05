# %%
import pandas as pd
import json

def merge(filename:str,station_name:pd.DataFrame) -> pd.DataFrame:
    df1 = pd.read_csv(filename)
    df2 = df1.rename(columns={'trnOpDate':'日期',
                    'staCode':'車站代碼',
                    'gateInComingCnt':'進站人數',
                    'gateOutGoingCnt':'出站人數'})
    df2['日期'] = pd.to_datetime(df2['日期'].astype(str))
    result_df = pd.merge(df2,station_name,left_on='車站代碼',right_on='編碼',how='left')
    return result_df

with open('每日各站進出站人數/車站基本資料集.json',encoding='utf-8') as file:
    json_data:list[dict] = json.load(file)

stations_name = pd.DataFrame(json_data,columns=['stationCode','stationName','stationAddrTw'])
stations_name1 = stations_name.rename(columns={'stationCode':'編碼',
                      'stationName':'車站名稱',
                      'stationAddrTw':'地址'})
stations_name1['編碼'] = stations_name1['編碼'].astype(int)

merge(filename='每日各站進出站人數/每日各站進出站人數2020.csv',station_name=stations_name1)
# Out:
#               日期  車站代碼  進站人數  出站人數    編碼 車站名稱  \
# 0     2020-01-01   900  7552  8154   900   基隆
# 1     2020-01-01   910  1020  1135   910   三坑
# 2     2020-01-01   920  1623  1972   920   八堵
# 3     2020-01-01   930  4130  4813   930   七堵
# 4     2020-01-01   940  1818  2128   940   百福
# ...          ...   ...   ...   ...   ...  ...
# 86927 2020-12-31  7360  3523  3602  7360   瑞芳
# 86928 2020-12-31  7361     3    18  7361  海科館
# 86929 2020-12-31  7362    28    34  7362  八斗子
# 86930 2020-12-31  7380   609   604  7380  四腳亭
# 86931 2020-12-31  7390   377   444  7390   暖暖
#
#                                                   地址
# 0                                        基隆市仁愛區港西街5號
# 1                                 基隆市仁愛區德厚里龍安街 206 號
# 2                                 基隆市暖暖區八南里八堵路 142 號
# 3                                   基隆市七堵區長興里東新街 2 號
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號
# ...                                              ...
# 86927                            新北市瑞芳區龍潭里明燈路三段 82 號
# 86928                                      基隆市中正區長潭里
# 86929  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 86930                              新北市瑞芳區吉慶里中央路 65 號
# 86931                              基隆市暖暖區暖暖里暖暖街 51 號
#
# [86932 rows x 7 columns]

# %%
import os
current_path = os.path.abspath(__name__) #目前執行檔案的絕對路徑
main_path = os.path.dirname(current_path) #取得目前執行的目錄的絕對路徑

'每日各站進出站人數'
dataFolder_path = os.path.join(main_path,'每日各站進出站人數') #取得放資料的目錄
os.listdir(dataFolder_path) #取得資料目錄的檔案名稱
# Out:
# ['每日各站進出站人數2022.csv',
#  '每日各站進出站人數2023.csv',
#  '每日各站進出站人數2021.csv',
#  '每日各站進出站人數2020.csv',
#  'manifest.csv',
#  '每日各站進出站人數20190423-20191231.csv',
#  '車站基本資料集.json',
#  'schema.csv']

# %%
import os
current_path = os.path.abspath(__name__) #目前執行檔案的絕對路徑
main_path = os.path.dirname(current_path) #取得目前執行的目錄的絕對路徑

'每日各站進出站人數'
dataFolder_path = os.path.join(main_path,'每日各站進出站人數') #取得放資料的目錄
filenames = os.listdir(dataFolder_path) #取得資料目錄的檔案名稱
names = list(filter(lambda name: '每日各站進出站人數' in name,filenames))
for name in names:
    print(os.path.join(dataFolder_path,name))
# Out:
# /workspaces/2024-05-05/lesson19/每日各站進出站人數/每日各站進出站人數2022.csv
# /workspaces/2024-05-05/lesson19/每日各站進出站人數/每日各站進出站人數2023.csv
# /workspaces/2024-05-05/lesson19/每日各站進出站人數/每日各站進出站人數2021.csv
# /workspaces/2024-05-05/lesson19/每日各站進出站人數/每日各站進出站人數2020.csv
# /workspaces/2024-05-05/lesson19/每日各站進出站人數/每日各站進出站人數20190423-20191231.csv

# %%
import os
current_path = os.path.abspath(__name__) #目前執行檔案的絕對路徑
main_path = os.path.dirname(current_path) #取得目前執行的目錄的絕對路徑

'每日各站進出站人數'
dataFolder_path = os.path.join(main_path,'每日各站進出站人數') #取得放資料的目錄
filenames = os.listdir(dataFolder_path) #取得資料目錄的檔案名稱
names = list(filter(lambda name: '每日各站進出站人數' in name,filenames)) #lambda
abs_names = [os.path.join(dataFolder_path,name) for name in names] #list comprehension
all_data = [merge(filename=abs_n,station_name=stations_name1) for abs_n in abs_names] #list comprehension
all_data
# Out:
# [              日期  車站代碼  進站人數  出站人數    編碼 車站名稱  \
#  0     2022-01-01   900  8645  8526   900   基隆
#  1     2022-01-01   910   996  1243   910   三坑
#  2     2022-01-01   920  1369  1711   920   八堵
#  3     2022-01-01   930  3663  4535   930   七堵
#  4     2022-01-01   940  1532  1845   940   百福
#  ...          ...   ...   ...   ...   ...  ...
#  86547 2022-12-31  7360  3984  3893  7360   瑞芳
#  86548 2022-12-31  7361    92   115  7361  海科館
#  86549 2022-12-31  7362   131   159  7362  八斗子
#  86550 2022-12-31  7380   494   426  7380  四腳亭
#  86551 2022-12-31  7390   313   274  7390   暖暖
#
#                                                    地址
#  0                                        基隆市仁愛區港西街5號
#  1                                 基隆市仁愛區德厚里龍安街 206 號
#  2                                 基隆市暖暖區八南里八堵路 142 號
#  3                                   基隆市七堵區長興里東新街 2 號
#  4                              基隆市七堵區堵南里明德三路 1 之 1 號
#  ...                                              ...
#  86547                            新北市瑞芳區龍潭里明燈路三段 82 號
#  86548                                      基隆市中正區長潭里
#  86549  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
#  86550                              新北市瑞芳區吉慶里中央路 65 號
#  86551                              基隆市暖暖區暖暖里暖暖街 51 號
#
#  [86552 rows x 7 columns],
#                日期  車站代碼  進站人數  出站人數    編碼 車站名稱  \
#  0     2023-01-01   900  8030  8241   900   基隆
#  1     2023-01-01   910  1017  1326   910   三坑
#  2     2023-01-01   920  1400  1705   920   八堵
#  3     2023-01-01   930  3558  4398   930   七堵
#  4     2023-01-01   940  1509  1815   940   百福
#  ...          ...   ...   ...   ...   ...  ...
#  86604 2023-12-31  7360  7916  8252  7360   瑞芳
#  86605 2023-12-31  7361   164   195  7361  海科館
#  86606 2023-12-31  7362   652   720  7362  八斗子
#  86607 2023-12-31  7380  1526   656  7380  四腳亭
#  86608 2023-12-31  7390   576   447  7390   暖暖
#
#                                                    地址
#  0                                        基隆市仁愛區港西街5號
#  1                                 基隆市仁愛區德厚里龍安街 206 號
#  2                                 基隆市暖暖區八南里八堵路 142 號
#  3                                   基隆市七堵區長興里東新街 2 號
#  4                              基隆市七堵區堵南里明德三路 1 之 1 號
#  ...                                              ...
#  86604                            新北市瑞芳區龍潭里明燈路三段 82 號
#  86605                                      基隆市中正區長潭里
#  86606  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
#  60125 2019-12-31  7361   146   142  7361  海科館
#  60126 2019-12-31  7362   116   134  7362  八斗子
#  60127 2019-12-31  7380   654   585  7380  四腳亭
#  60128 2019-12-31  7390   448   396  7390   暖暖
#
#                                                    地址
#  0                                        基隆市仁愛區港西街5號
#  1                                 基隆市仁愛區德厚里龍安街 206 號
#  2                                 基隆市暖暖區八南里八堵路 142 號
#  3                                   基隆市七堵區長興里東新街 2 號
#  4                              基隆市七堵區堵南里明德三路 1 之 1 號
#  ...                                              ...
#  60124                            新北市瑞芳區龍潭里明燈路三段 82 號
#  60125                                      基隆市中正區長潭里
#  60126  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
#  60127                              新北市瑞芳區吉慶里中央路 65 號
#  60128                              基隆市暖暖區暖暖里暖暖街 51 號
#
#  [60129 rows x 7 columns]]

# %%
import os
current_path = os.path.abspath(__name__) #目前執行檔案的絕對路徑
main_path = os.path.dirname(current_path) #取得目前執行的目錄的絕對路徑

'每日各站進出站人數'
dataFolder_path = os.path.join(main_path,'每日各站進出站人數') #取得放資料的目錄
filenames = os.listdir(dataFolder_path) #取得資料目錄的檔案名稱
names = list(filter(lambda name: '每日各站進出站人數' in name,filenames)) #lambda
abs_names = [os.path.join(dataFolder_path,name) for name in names] #list comprehension
all_data = [merge(filename=abs_n,station_name=stations_name1) for abs_n in abs_names] #list comprehension
result = pd.concat(all_data,ignore_index=True)
result1 = result.set_index('日期')
result2 = result1.sort_index().reindex(columns=['車站名稱','地址','進站人數','出站人數'])
result2
# Out:
#            車站名稱                    地址   進站人數   出站人數
# 日期
# 2019-04-23  海科館             基隆市中正區長潭里     72     52
# 2019-04-23   潮州    屏東縣潮州鎮新榮里信義路 111 號   3192   3203
# 2019-04-23   崁頂    屏東縣崁頂鄉崁頂村中正路 122 號    135    191
# 2019-04-23   南州     屏東縣南州鄉仁里村仁里路 86 號    533    424
# 2019-04-23   鎮安      屏東縣林邊鄉鎮安村永和路 4 號     15     14
# ...         ...                   ...    ...    ...
# 2023-12-31   成功  臺中市烏日區榮泉里中山路三段 550 號   1229   3101
# 2023-12-31   彰化      彰化縣彰化市長樂里三民路 1 號  19617  16699
# 2023-12-31   花壇    彰化縣花壇鄉花壇村中正路 370 號   1864   1532
# 2023-12-31   潭子     臺中市潭子區中山路二段352-1號   3517   3091
# 2023-12-31  四腳亭     新北市瑞芳區吉慶里中央路 65 號   1526    656
#
# [406761 rows x 4 columns]

# %%
import os
current_path = os.path.abspath(__name__) #目前執行檔案的絕對路徑
main_path = os.path.dirname(current_path) #取得目前執行的目錄的絕對路徑

'每日各站進出站人數'
dataFolder_path = os.path.join(main_path,'每日各站進出站人數') #取得放資料的目錄
filenames = os.listdir(dataFolder_path) #取得資料目錄的檔案名稱
names = list(filter(lambda name: '每日各站進出站人數' in name,filenames)) #lambda
abs_names = [os.path.join(dataFolder_path,name) for name in names] #list comprehension
all_data = [merge(filename=abs_n,station_name=stations_name1) for abs_n in abs_names] #list comprehension
result = pd.concat(all_data,ignore_index=True)
result1 = result.set_index('日期')
result2 = result1.sort_index().reindex(columns=['車站名稱','地址','進站人數','出站人數'])
result2.to_csv("2019~2023進出站人口數.csv")
