# %%
import pandas as pd

df1 = pd.read_csv('各鄉鎮市區人口密度/102.csv')
df1 = pd.read_csv('各鄉鎮市區人口密度/104.csv')
df1 = pd.read_csv('各鄉鎮市區人口密度/103.csv')


df2 = df1.rename(columns={'statistic_yyy':'統計年',
                    'site_id':'區域別',
                    'people_total':'年底人口數',
                    'area':'土地面積',
                    'population_density':'人口密度'})
df2
# Out:
#      統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    103                                             新北市板橋區  555914  23.1373
# 2    103                                             新北市三重區  389325   16.317
# 3    103                                             新北市中和區  415226   20.144
# 4    103                                             新北市永和區  227267   5.7138
# ..   ...                                                ...     ...      ...
# 370  103                                               南沙群島       …   0.4896
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  　　　2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.489...     NaN      NaN
# 374  NaN     　　   　，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
#
#       人口密度
# 0     人口密度
# 1    24027
# ...
